# %% [markdown]
# # 1. Create a function that takes a list and returns a new list containing only prime numbers.

# %%
def is_prime(n):
    if n == 1:
        return False
    for i in range(2,n//2+1):
        if n % i == 0:
            return False
    return True

def filter_primes(lst):
    return [i for i in lst if is_prime(i)]

print(filter_primes([7, 9, 3, 9, 10, 11, 27]) )
print(filter_primes([10007, 1009, 1007, 27, 147, 77, 1001, 70]))
print(filter_primes([1009, 10, 10, 10, 3, 33, 9, 4, 1, 61, 63, 69, 1087, 1091, 1093, 1097]))
# Out:
# [7, 3, 11]
# [10007, 1009]
# [1009, 3, 61, 1087, 1091, 1093, 1097]

# %% [markdown]
# # 2. Once a water balloon pops, is soaks the area around it. The ground gets drier the further away you travel from the balloon.
#
# The effect of a water balloon popping can be modeled using a list. Create a function that takes a list which takes the pre-pop state and returns the state after the balloon is popped. The pre-pop state will contain at most a single balloon, whose size is represented by the only non-zero element.

# %%
def pop(lst):
    if lst.count(0) == 1:
        return 0
    ballon = list(set(lst))
    ballon.remove(0)
    ballon_pos = lst.index(ballon[0])
    for i in range(1,ballon[0]+1):
        lst[ballon_pos-i]=lst[ballon_pos+i]=ballon[0]-1
        ballon[0] -= 1
    return lst
    
print(pop([0, 0, 0, 0, 4, 0, 0, 0, 0]))
print(pop([0, 0, 0, 3, 0, 0, 0]))
print(pop([0, 0, 2, 0, 0]))
print(pop([0]))
# Out:
# [0, 1, 2, 3, 4, 3, 2, 1, 0]
# [0, 1, 2, 3, 2, 1, 0]
# [0, 1, 2, 1, 0]
# 0

# %% [markdown]
# # 3. "Loves me, loves me not" is a traditional game in which a person plucks off all the petals of a flower one by one, saying the phrase "Loves me" and "Loves me not" when determining whether the one that they love, loves them back.
#
# Given a number of petals, return a string which repeats the phrases "Loves me" and "Loves me not" for every alternating petal, and return the last phrase in all caps. Remember to put a comma and space between phrases.

# %%
def loves_me(n):
    phrase = ''
    even = "Loves me not"
    odd = "Loves me"
    for i in range(1,n+1):
        if i % 2 == 0:
            if i==n:
                phrase += even.upper()
            else:
                phrase += even + ", "
        else:
            if i == n:
                phrase += odd.upper()
            else:
                phrase += odd + ", "
    return phrase

print(loves_me(3))
print(loves_me(6))
print(loves_me(1))
# Out:
# Loves me, Loves me not, LOVES ME
# Loves me, Loves me not, Loves me, Loves me not, Loves me, LOVES ME NOT
# LOVES ME

# %% [markdown]
# # 4. Write a function that sorts each string in a list by the letter in alphabetic ascending order (a-z).

# %%
import re
def sort_by_letter(string):
    letters = {''.join(re.findall(r'[a-z]',i)):i for i in string}
    sorted_letters = dict(sorted(letters.items()))
    return list(sorted_letters.values())
    
print(sort_by_letter(["932c", "832u32", "2344b"]))
print(sort_by_letter(["99a", "78b", "c2345", "11d"]))
print(sort_by_letter(["572z", "5y5", "304q2"]))
print(sort_by_letter([]))
# Out:
# ['2344b', '932c', '832u32']
# ['99a', '78b', 'c2345', '11d']
# ['304q2', '5y5', '572z']
# []

# %% [markdown]
# # 5. There are three cups on a table, at positions A, B, and C. At the start, there is a ball hidden under the cup at position B.
#
# ![image.png](attachment:image.png)
#
#
#
#
# However, I perform several swaps on the cups, which is notated as two letters. For example, if I swap the cups at positions A and B, I could notate this as AB or BA.
#
# Create a function that returns the letter position that the ball is at, once I finish swapping the cups. The swaps will be given to you as a list.

# %%
def cup_swapping(swaps):
    ball = 'B'
    for i in swaps:
        swap_list = list(i)
        if ball in swap_list:
            swap_list.remove(ball)
            ball = ''.join(swap_list)
    return ball
            
cup_swapping(["AB", "CA", "AB"])
# Out:
# 'C'
