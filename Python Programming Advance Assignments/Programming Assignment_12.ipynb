# %% [markdown]
# # 1. For this challenge, forget how to add two numbers together. The best explanation on what to do for this function is this meme:
#
#    ![image.png](attachment:image.png)

# %%
def meme_sum(n1,n2):
    n1_str,n2_str=str(n1),str(n2)
    max_len = max(len(n1_str),len(n2_str))
    n1_difflen,n2_difflen = max_len-len(n1_str),max_len - len(n2_str)
    n1_str,n2_str = '0'*n1_difflen + n1_str, '0'*n2_difflen + n2_str
    result = ''
    for i in range(max_len):
        result += str(int(n1_str[i])+int(n2_str[i]))
        
    return int(result)
print(meme_sum(26, 39))
print(meme_sum(122, 81))
print(meme_sum(1222, 30277))
# Out:
# 515
# 1103
# 31499

# %% [markdown]
# # 2. Given an integer, create a function that returns the next prime. If the number is prime, return the number itself.

# %%
def is_prime(n):
    if n == 1:
        return False
    for i in range(2,n//2+1):
        if n % i == 0:
            return False
    return True

def next_prime(num):
    while True:
        if is_prime(num):
            return num
        else:
            num += 1
            
print(next_prime(12))
print(next_prime(24))
print(next_prime(11))
# Out:
# 13
# 29
# 11

# %% [markdown]
# # 3. If a person traveled up a hill for 18mins at 20mph and then traveled back down the same path at 60mph then their average speed traveled was 30mph.
#
# Write a function that returns the average speed traveled given an uphill time, uphill rate and a downhill rate. Uphill time is given in minutes. Return the rate as an integer (mph). No rounding is necessary.

# %%
def ave_spd(t,s1,s2):
    return (2*s1*s2)/(s1+s2)

print(ave_spd(18, 20, 60))
print(ave_spd(30, 10, 30))
print(ave_spd(30, 8, 24))
# Out:
# 30.0
# 15.0
# 12.0

# %% [markdown]
# # 4. The Kempner Function, applied to a composite number, permits to find the smallest integer greater than zero whose factorial is exactly divided by the number.
#
#     kempner(6) ➞ 3
#
#     1! = 1 % 6 > 0
#     2! = 2 % 6 > 0
#     3! = 6 % 6 === 0
#
#     kempner(10) ➞ 5
#
#     1! = 1 % 10 > 0
#     2! = 2 % 10 > 0
#     3! = 6 % 10 > 0
#     4! = 24 % 10 > 0
#     5! = 120 % 10 === 0
#
#     A Kempner Function applied to a prime will always return the prime itself.
#
#     kempner(2) ➞ 2
#     kempner(5) ➞ 5
#
#     Given an integer n, implement a Kempner Function.

# %%
def is_prime(n):
    if n == 1:
        return False
    for i in range(2,n//2+1):
        if n % i == 0:
            return False
    return True

def kempner(n):
    if is_prime(n):
        return n
    else:
        fact = [1]
        i = 1
        while True:
            if fact[-1]%n == 0:
                return i-1
            fact.append(i*fact[i-1])
            i += 1
            
print(kempner(6))
print(kempner(10))
print(kempner(2))
# Out:
# 3
# 5
# 2

# %% [markdown]
# # 5. You work in a factory, and your job is to take items from a conveyor belt and pack them into boxes. Each box can hold a maximum of 10 kgs. Given a list containing the weight (in kg) of each item, how many boxes would you need to pack all of the items?

# %%
def boxes(lst):
    no_boxes = 0
    total = 0
    for i in range(len(lst)):
        if lst[i] + total <=10 and i == len(lst)-1:
            no_boxes += 1
        elif lst[i] + total <=10:
            total += lst[i]
        else:
            no_boxes += 1
            total = lst[i]
    return no_boxes

boxes([2, 1, 2, 5, 4, 3, 6, 1, 1, 9, 3, 2])
# Out:
# 5
